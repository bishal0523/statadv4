# %%
# Q1: Difference between a t-test and a z-test
# t-test: Used when the sample size is small (typically n < 30) or when the population standard deviation is unknown.
# z-test: Used when the sample size is large (typically n >= 30) and the population standard deviation is known.
# Example Scenarios:

# t-test: Suppose you have a small sample of 20 students, and you want to test whether their average score on a test differs from the national average. Since the sample size is small and the population standard deviation is unknown, you would use a t-test.
# z-test: Suppose a factory produces thousands of widgets daily, and you want to test if the average weight of widgets produced is 5 grams, using a sample of 100 widgets. Since the sample size is large and the population standard deviation is known, you would use a z-test.
# Q2: One-tailed vs Two-tailed Tests
# One-tailed test: Tests for a difference in a specific direction (either greater than or less than).
# Two-tailed test: Tests for any difference, regardless of direction (both greater than and less than).
# Example:

# One-tailed test: You want to test if a new teaching method is better than the old method (i.e., scores are higher). This is a one-tailed test.
# Two-tailed test: You want to test if a new teaching method has any effect (either better or worse) on student scores compared to the old method. This is a two-tailed test.
# Q3: Type 1 and Type 2 Errors
# Type 1 Error (False Positive): Rejecting the null hypothesis when it is actually true.
# Type 2 Error (False Negative): Failing to reject the null hypothesis when it is actually false.
# Example Scenarios:

# Type 1 Error: A drug company claims that their new drug is effective, but in reality, it is not. A Type 1 error occurs if the test wrongly shows the drug to be effective.
# Type 2 Error: A security system fails to detect an intruder. A Type 2 error occurs if the test wrongly indicates that no intruder is present when there is one.
# Q4: Bayes's Theorem
# Bayes's Theorem is a way to find a probability when we know certain other probabilities. It is expressed as:
# 𝑃
# (
# 𝐴
# ∣
# 𝐵
# )
# =
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# )
# ⋅
# 𝑃
# (
# 𝐴
# )
# 𝑃
# (
# 𝐵
# )
# P(A∣B)= 
# P(B)
# P(B∣A)⋅P(A)
# ​
 

# Example:
# Suppose 1% of a population has a disease. A test for the disease is 99% accurate. What is the probability that a person who tests positive actually has the disease?

# Given:

# 𝑃
# (
# 𝐷
# )
# =
# 0.01
# P(D)=0.01 (Probability of having the disease)
# 𝑃
# (
# ¬
# 𝐷
# )
# =
# 0.99
# P(¬D)=0.99 (Probability of not having the disease)
# 𝑃
# (
# 𝑇
# ∣
# 𝐷
# )
# =
# 0.99
# P(T∣D)=0.99 (Probability of a positive test given disease)
# 𝑃
# (
# 𝑇
# ∣
# ¬
# 𝐷
# )
# =
# 0.01
# P(T∣¬D)=0.01 (Probability of a positive test given no disease)
# Bayes's Theorem:
# 𝑃
# (
# 𝐷
# ∣
# 𝑇
# )
# =
# 𝑃
# (
# 𝑇
# ∣
# 𝐷
# )
# ⋅
# 𝑃
# (
# 𝐷
# )
# 𝑃
# (
# 𝑇
# ∣
# 𝐷
# )
# ⋅
# 𝑃
# (
# 𝐷
# )
# +
# 𝑃
# (
# 𝑇
# ∣
# ¬
# 𝐷
# )
# ⋅
# 𝑃
# (
# ¬
# 𝐷
# )
# P(D∣T)= 
# P(T∣D)⋅P(D)+P(T∣¬D)⋅P(¬D)
# P(T∣D)⋅P(D)
# ​
 
# 𝑃
# (
# 𝐷
# ∣
# 𝑇
# )
# =
# 0.99
# ⋅
# 0.01
# 0.99
# ⋅
# 0.01
# +
# 0.01
# ⋅
# 0.99
# =
# 0.0099
# 0.0099
# +
# 0.0099
# =
# 0.0099
# 0.0198
# =
# 0.5
# P(D∣T)= 
# 0.99⋅0.01+0.01⋅0.99
# 0.99⋅0.01
# ​
#  = 
# 0.0099+0.0099
# 0.0099
# ​
#  = 
# 0.0198
# 0.0099
# ​
#  =0.5

# Q5: Confidence Interval
# Confidence Interval: A range of values that is likely to contain the population parameter with a certain level of confidence.

# Calculation:
# 𝐶
# 𝐼
# =
# 𝑥
# ˉ
# ±
# 𝑍
# (
# 𝜎
# 𝑛
# )
# CI= 
# x
# ˉ
#  ±Z( 
# n
# ​
 
# σ
# ​
#  )
# Where:

# 𝑥
# ˉ
# x
# ˉ
#   is the sample mean
# 𝑍
# Z is the z-score corresponding to the desired confidence level
# 𝜎
# σ is the population standard deviation
# 𝑛
# n is the sample size
# Example:
# For a sample mean 
# 𝑥
# ˉ
# =
# 50
# x
# ˉ
#  =50, standard deviation 
# 𝜎
# =
# 5
# σ=5, sample size 
# 𝑛
# =
# 30
# n=30, and a 95% confidence level (
# 𝑍
# =
# 1.96
# Z=1.96):
# 𝐶
# 𝐼
# =
# 50
# ±
# 1.96
# (
# 5
# 30
# )
# CI=50±1.96( 
# 30
# ​
 
# 5
# ​
#  )
# 𝐶
# 𝐼
# =
# 50
# ±
# 1.79
# CI=50±1.79
# 𝐶
# 𝐼
# =
# [
# 48.21
# ,
# 51.79
# ]
# CI=[48.21,51.79]

# Q6: Bayes' Theorem Calculation Example
# Problem:
# Suppose 2% of people in a town are criminals. A surveillance system detects criminals with 99% accuracy and non-criminals with 2% false positive rate. If a person is flagged by the system, what is the probability they are a criminal?

# Given:

# 𝑃
# (
# 𝐶
# )
# =
# 0.02
# P(C)=0.02 (Probability of being a criminal)
# 𝑃
# (
# ¬
# 𝐶
# )
# =
# 0.98
# P(¬C)=0.98 (Probability of not being a criminal)
# 𝑃
# (
# 𝐹
# ∣
# 𝐶
# )
# =
# 0.99
# P(F∣C)=0.99 (Probability of flagging given criminal)
# 𝑃
# (
# 𝐹
# ∣
# ¬
# 𝐶
# )
# =
# 0.02
# P(F∣¬C)=0.02 (Probability of flagging given non-criminal)
# Bayes's Theorem:
# 𝑃
# (
# 𝐶
# ∣
# 𝐹
# )
# =
# 𝑃
# (
# 𝐹
# ∣
# 𝐶
# )
# ⋅
# 𝑃
# (
# 𝐶
# )
# 𝑃
# (
# 𝐹
# ∣
# 𝐶
# )
# ⋅
# 𝑃
# (
# 𝐶
# )
# +
# 𝑃
# (
# 𝐹
# ∣
# ¬
# 𝐶
# )
# ⋅
# 𝑃
# (
# ¬
# 𝐶
# )
# P(C∣F)= 
# P(F∣C)⋅P(C)+P(F∣¬C)⋅P(¬C)
# P(F∣C)⋅P(C)
# ​
 
# 𝑃
# (
# 𝐶
# ∣
# 𝐹
# )
# =
# 0.99
# ⋅
# 0.02
# 0.99
# ⋅
# 0.02
# +
# 0.02
# ⋅
# 0.98
# P(C∣F)= 
# 0.99⋅0.02+0.02⋅0.98
# 0.99⋅0.02
# ​
 
# 𝑃
# (
# 𝐶
# ∣
# 𝐹
# )
# =
# 0.0198
# 0.0198
# +
# 0.0196
# =
# 0.0198
# 0.0394
# ≈
# 0.5025
# P(C∣F)= 
# 0.0198+0.0196
# 0.0198
# ​
#  = 
# 0.0394
# 0.0198
# ​
#  ≈0.5025

# Q7: 95% Confidence Interval Calculation
# Given:

# Sample mean 
# 𝑥
# ˉ
# =
# 50
# x
# ˉ
#  =50
# Standard deviation 
# 𝜎
# =
# 5
# σ=5
# Sample size 
# 𝑛
# =
# 30
# n=30
# 95% confidence level (
# 𝑍
# =
# 1.96
# Z=1.96)
# 𝐶
# 𝐼
# =
# 50
# ±
# 1.96
# (
# 5
# 30
# )
# CI=50±1.96( 
# 30
# ​
 
# 5
# ​
#  )
# 𝐶
# 𝐼
# =
# 50
# ±
# 1.79
# CI=50±1.79
# 𝐶
# 𝐼
# =
# [
# 48.21
# ,
# 51.79
# ]
# CI=[48.21,51.79]

# Interpretation:
# We are 95% confident that the true population mean lies between 48.21 and 51.79.

# Q8: Margin of Error and Sample Size
# Margin of Error (MOE): Indicates the range within which we expect the true population parameter to lie.
# 𝑀
# 𝑂
# 𝐸
# =
# 𝑍
# (
# 𝜎
# 𝑛
# )
# MOE=Z( 
# n
# ​
 
# σ
# ​
#  )

# Effect of Sample Size:
# As the sample size increases, the margin of error decreases, resulting in a more precise estimate.

# Example:
# For 
# 𝑛
# =
# 30
# n=30 and 
# 𝑛
# =
# 100
# n=100 with 
# 𝜎
# =
# 5
# σ=5, 95% confidence level (
# 𝑍
# =
# 1.96
# Z=1.96):

# 𝑀
# 𝑂
# 𝐸
# 30
# =
# 1.96
# (
# 5
# 30
# )
# ≈
# 1.79
# MOE 
# 30
# ​
#  =1.96( 
# 30
# ​
 
# 5
# ​
#  )≈1.79
# 𝑀
# 𝑂
# 𝐸
# 100
# =
# 1.96
# (
# 5
# 100
# )
# =
# 0.98
# MOE 
# 100
# ​
#  =1.96( 
# 100
# ​
 
# 5
# ​
#  )=0.98
# Q9: Z-score Calculation
# Given:

# Data point 
# 𝑋
# =
# 75
# X=75
# Population mean 
# 𝜇
# =
# 70
# μ=70
# Population standard deviation 
# 𝜎
# =
# 5
# σ=5
# 𝑍
# =
# 𝑋
# −
# 𝜇
# 𝜎
# =
# 75
# −
# 70
# 5
# =
# 1
# Z= 
# σ
# X−μ
# ​
#  = 
# 5
# 75−70
# ​
#  =1

# Interpretation:
# The data point is 1 standard deviation above the mean.

# Q10: Hypothesis Test for Weight Loss Drug using t-test
# Given:

# Sample mean 
# 𝑥
# ˉ
# =
# 6
# x
# ˉ
#  =6
# Standard deviation 
# 𝑠
# =
# 2.5
# s=2.5
# Sample size 
# 𝑛
# =
# 50
# n=50
# Null hypothesis 
# 𝐻
# 0
# :
# 𝜇
# =
# 0
# H 
# 0
# ​
#  :μ=0
# Alternative hypothesis 
# 𝐻
# 1
# :
# 𝜇
# ≠
# 0
# H 
# 1
# ​
#  :μ
# 
# =0
# Significance level 
# 𝛼
# =
# 0.05
# α=0.05
# 𝑡
# =
# 𝑥
# ˉ
# −
# 𝜇
# 0
# 𝑠
# /
# 𝑛
# =
# 6
# −
# 0
# 2.5
# /
# 50
# =
# 16.97
# t= 
# s/ 
# n
# ​
 
# x
# ˉ
#  −μ 
# 0
# ​
 
# ​
#  = 
# 2.5/ 
# 50
# ​
 
# 6−0
# ​
#  =16.97

# Degrees of freedom 
# 𝑑
# 𝑓
# =
# 𝑛
# −
# 1
# =
# 49
# df=n−1=49.
# Critical t-value for 
# 𝛼
# =
# 0.05
# α=0.05 (two-tailed) and 
# 𝑑
# 𝑓
# =
# 49
# df=49 is approximately 2.0096.

# Since 
# 𝑡
# =
# 16.97
# >
# 2.0096
# t=16.97>2.0096, we reject the null hypothesis. The drug is significantly effective.

# Q11: Confidence Interval for Proportion
# Given:

# Sample size 
# 𝑛
# =
# 500
# n=500
# Proportion 
# 𝑝
# ^
# =
# 0.65
# p
# ^
# ​
#  =0.65
# Confidence level 
# 95
# %
# 95% (Z-value for 95% confidence level is 1.96)
# The formula for the confidence interval for a proportion is:
# 𝐶
# 𝐼
# =
# 𝑝
# ^
# ±
# 𝑍
# 𝑝
# ^
# (
# 1
# −
# 𝑝
# ^
# )
# 𝑛
# CI= 
# p
# ^
# ​
#  ±Z 
# n
# p
# ^
# ​
#  (1− 
# p
# ^
# ​
#  )
# ​
 
# ​
 

# Let's calculate:
# 𝐶
# 𝐼
# =
# 0.65
# ±
# 1.96
# 0.65
# ×
# 0.35
# 500
# CI=0.65±1.96 
# 500
# 0.65×0.35
# ​
 
# ​
 
# 𝐶
# 𝐼
# =
# 0.65
# ±
# 1.96
# 0.000455
# CI=0.65±1.96 
# 0.000455
# ​
 
# 𝐶
# 𝐼
# =
# 0.65
# ±
# 1.96
# ×
# 0.0213
# CI=0.65±1.96×0.0213
# 𝐶
# 𝐼
# =
# 0.65
# ±
# 0.0417
# CI=0.65±0.0417
# 𝐶
# 𝐼
# =
# [
# 0.6083
# ,
# 0.6917
# ]
# CI=[0.6083,0.6917]

# Q12: Hypothesis Test for Two Teaching Methods
# Given:

# Sample A: 
# 𝑥
# ˉ
# 𝐴
# =
# 85
# x
# ˉ
  
# A
# ​
#  =85, 
# 𝑠
# 𝐴
# =
# 6
# s 
# A
# ​
#  =6, 
# 𝑛
# 𝐴
# =
# 30
# n 
# A
# ​
#  =30
# Sample B: 
# 𝑥
# ˉ
# 𝐵
# =
# 82
# x
# ˉ
  
# B
# ​
#  =82, 
# 𝑠
# 𝐵
# =
# 5
# s 
# B
# ​
#  =5, 
# 𝑛
# 𝐵
# =
# 30
# n 
# B
# ​
#  =30
# Significance level 
# 𝛼
# =
# 0.01
# α=0.01
# The formula for the t-test for two independent samples is:
# 𝑡
# =
# 𝑥
# ˉ
# 𝐴
# −
# 𝑥
# ˉ
# 𝐵
# 𝑠
# 𝐴
# 2
# 𝑛
# 𝐴
# +
# 𝑠
# 𝐵
# 2
# 𝑛
# 𝐵
# t= 
# n 
# A
# ​
 
# s 
# A
# 2
# ​
 
# ​
#  + 
# n 
# B
# ​
 
# s 
# B
# 2
# ​
 
# ​
 
# ​
 
# x
# ˉ
  
# A
# ​
#  − 
# x
# ˉ
  
# B
# ​
 
# ​
 

# Let's calculate:
# 𝑡
# =
# 85
# −
# 82
# 6
# 2
# 30
# +
# 5
# 2
# 30
# t= 
# 30
# 6 
# 2
 
# ​
#  + 
# 30
# 5 
# 2
 
# ​
 
# ​
 
# 85−82
# ​
 
# 𝑡
# =
# 3
# 36
# 30
# +
# 25
# 30
# t= 
# 30
# 36
# ​
#  + 
# 30
# 25
# ​
 
# ​
 
# 3
# ​
 
# 𝑡
# =
# 3
# 2.033
# t= 
# 2.033
# ​
 
# 3
# ​
 
# 𝑡
# =
# 3
# 1.426
# t= 
# 1.426
# 3
# ​
 
# 𝑡
# =
# 2.104
# t=2.104

# Degrees of freedom (using a conservative estimate):
# 𝑑
# 𝑓
# ≈
# min
# ⁡
# (
# 𝑛
# 𝐴
# −
# 1
# ,
# 𝑛
# 𝐵
# −
# 1
# )
# =
# 29
# df≈min(n 
# A
# ​
#  −1,n 
# B
# ​
#  −1)=29

# The critical t-value for 
# 𝛼
# =
# 0.01
# α=0.01 (two-tailed) and 
# 𝑑
# 𝑓
# =
# 29
# df=29 is approximately 2.756.

# Since 
# 𝑡
# =
# 2.104
# <
# 2.756
# t=2.104<2.756, we fail to reject the null hypothesis. There is no significant difference between the two teaching methods at the 0.01 significance level.

# Q13: 90% Confidence Interval for the Population Mean
# Given:

# Population mean 
# 𝜇
# =
# 60
# μ=60
# Standard deviation 
# 𝜎
# =
# 8
# σ=8
# Sample size 
# 𝑛
# =
# 50
# n=50
# Sample mean 
# 𝑥
# ˉ
# =
# 65
# x
# ˉ
#  =65
# Confidence level 
# 90
# %
# 90% (Z-value for 90% confidence level is 1.645)
# The formula for the confidence interval is:
# 𝐶
# 𝐼
# =
# 𝑥
# ˉ
# ±
# 𝑍
# (
# 𝜎
# 𝑛
# )
# CI= 
# x
# ˉ
#  ±Z( 
# n
# ​
 
# σ
# ​
#  )

# Let's calculate:
# 𝐶
# 𝐼
# =
# 65
# ±
# 1.645
# (
# 8
# 50
# )
# CI=65±1.645( 
# 50
# ​
 
# 8
# ​
#  )
# 𝐶
# 𝐼
# =
# 65
# ±
# 1.645
# (
# 8
# 7.071
# )
# CI=65±1.645( 
# 7.071
# 8
# ​
#  )
# 𝐶
# 𝐼
# =
# 65
# ±
# 1.645
# ×
# 1.131
# CI=65±1.645×1.131
# 𝐶
# 𝐼
# =
# 65
# ±
# 1.86
# CI=65±1.86
# 𝐶
# 𝐼
# =
# [
# 63.14
# ,
# 66.86
# ]
# CI=[63.14,66.86]

# Q14: Hypothesis Test for Caffeine on Reaction Time
# Given:

# Sample mean 
# 𝑥
# ˉ
# =
# 0.25
# x
# ˉ
#  =0.25
# Standard deviation 
# 𝑠
# =
# 0.05
# s=0.05
# Sample size 
# 𝑛
# =
# 30
# n=30
# Null hypothesis 
# 𝐻
# 0
# :
# 𝜇
# =
# 0
# H 
# 0
# ​
#  :μ=0
# Alternative hypothesis 
# 𝐻
# 1
# :
# 𝜇
# ≠
# 0
# H 
# 1
# ​
#  :μ
# 
# =0
# Significance level 
# 𝛼
# =
# 0.10
# α=0.10
# The formula for the t-test is:
# 𝑡
# =
# 𝑥
# ˉ
# −
# 𝜇
# 0
# 𝑠
# /
# 𝑛
# t= 
# s/ 
# n
# ​
 
# x
# ˉ
#  −μ 
# 0
# ​
 
# ​
 

# Let's calculate:
# 𝑡
# =
# 0.25
# −
# 0
# 0.05
# /
# 30
# t= 
# 0.05/ 
# 30
# ​
 
# 0.25−0
# ​
 
# 𝑡
# =
# 0.25
# 0.0091
# t= 
# 0.0091
# 0.25
# ​
 
# 𝑡
# =
# 27.39
# t=27.39

# Degrees of freedom 
# 𝑑
# 𝑓
# =
# 𝑛
# −
# 1
# =
# 29
# df=n−1=29.
# The critical t-value for 
# 𝛼
# =
# 0.10
# α=0.10 (two-tailed) and 
# 𝑑
# 𝑓
# =
# 29
# df=29 is approximately 1.699.

# Since 
# 𝑡
# =
# 27.39
# >
# 1.699
# t=27.39>1.699, we reject the null hypothesis. The caffeine has a significant effect on reaction time at the 90% confidence level
